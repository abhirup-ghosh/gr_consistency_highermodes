# %%
import numpy as np
import matplotlib.pyplot as plt

import template_22 as phhsi
from pycbc  import  detector

# %%
def lnlike(param_vec, data, freq, psd, f_low, f_cut):
        """
        compute the log likelihood
        
        inputs: 
        param_vec : vector of parameters 
        dr, di, 
        freq : Fourier freq 
        psd : psd vector 
        flow,fcut
        
        output: 
        log_likelhood 
        """
        df = np.mean(np.diff(freq))

        N_low=np.int((f_low-freq[0])/df)
        N_cut=np.int((f_cut-freq[0])/df)

        Nls=np.int(f_low/df)  #N_low_signal
        Ncs=np.int(f_cut/df)  #N_cut_signal

        # unpacking the parameter vector 
        Mc, q, dL, i, t0, phi0, ra, sin_dec, pol = param_vec

        # generate the waveform 
        f, hpf, hcf = phhsi.phenomhh_waveform_SI(Mc, q, dL, i, t0, (phi0 %(2.*np.pi)), f_low, df, Ncs)

        # compute antenna patterns 
        Fp,Fc = detector.overhead_antenna_pattern(ra, np.arcsin(sin_dec), pol)

        signal=Fp*hpf+Fc*hcf

        like = -2.*df*np.real(np.dot(data[N_low:N_cut]-signal[Nls:Ncs],np.conj((data[N_low:N_cut]-signal[Nls:Ncs])/psd[N_low:N_cut])))

        return like#log-likelihood
    
def lnprior(param_vec):
        Mc, q, dL, i, t0, phi_0, ra, sin_dec, pol = param_vec
        if 1 < Mc < 200 and 0.05 < q <= 1. and  1.<dL<10000 and 0.<= i <= pi and -15.<= t0 <= 15. and -pi <= phi_0 <= 3.*pi and 0. <= ra < 2.*pi and -1. <= sin_dec <= 1. and 0. <= pol <= pi:
                return 2.*np.log(dL)+np.log(np.sin(i))
        return -np.inf

def lnprob(param_vec):
        lp = lnprior(param_vec)
        if not np.isfinite(lp):
                return -np.inf
        return lp + lnlike(param_vec, data, freq, psd, f_low, f_cut)

# %%
#data
freq, dr, di, psd = np.loadtxt('../injections/nsbh_sxs_20181209/BBH_M_140.00_iota_0.000_pol_0.000_t0_0_data.dat', unpack=True)
data = dr + 1j*di

#best-fit phenom_hm waveform

#parameters corresponding to best-fit phenom_hm waveform
Mc, q, dL, iota, t0, phi0, ra, sin_dec, pol = np.loadtxt('../injections/nsbh_sxs_20181209/BBH_M_140.00_iota_0.000_pol_0.000_t0_0_initial.dat', unpack=True)

f_low = 20.
f_cut = 999.
df = np.mean(np.diff(freq))
Ncs=np.int(f_cut/df)
f, hpf, hcf = phhsi.phenomhh_waveform_SI(Mc, q, dL, iota, t0, (phi0 %(2.*np.pi)), f_low, df, Ncs)
Fp,Fc = detector.overhead_antenna_pattern(ra, np.arcsin(sin_dec), pol)
best_fit_signal=Fp*hpf+Fc*hcf

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.loglog(freq, abs(data), label='SXS')
plt.loglog(f, abs(best_fit_signal), label='phenomhm')
plt.loglog(freq, np.sqrt(psd), label='PSD')
plt.xlim([f_low, 128.])
plt.ylim([1e-24, 1e-22])
plt.legend(loc='best')
plt.subplot(122)
plt.title('zoomed-out')
plt.loglog(freq, abs(data))
plt.loglog(f, abs(best_fit_signal))
plt.loglog(freq, np.sqrt(psd))
plt.ylim([1e-30, 1e-21])
plt.show()
# Out:
# f_Nyq = 1098.634953
# fM_band: 20.015189 Hz to 1098.604810 Hz
# fM_band: 0.013802 Hz to 0.757564 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035586 secs
# f0 = 0.013802 ini_offset_phen_p = 112.755411
# ...... generated the phen ampl in 0.051535 sec
# ...... generated the phen phase in 0.049569 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107562 secs
# mtot = 140.000000 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4

# %%
param_set = ['mc','q']
lnlike_data_map = {'mc':[],'q':[]}
lnlike_bfs_map = {'mc':[],'q':[]}
param_range_map = {'mc':np.linspace(35,45,50),'q':np.linspace(0.1,0.2,50)}

plt.figure(figsize=(10,5))
for (idx, param) in enumerate(param_set):
    param_range = param_range_map[param]
    for x in param_range:
        param_vec = mc_init, q_init, dL_init, iota_init, t0_init, phi0_init, ra_init, sin_dec_init, pol_init
        param_vec = list(param_vec)
        param_vec[idx] = x
        param_vec = tuple(param_vec)
        lnlike_data_map[param].append(lnlike(param_vec, data, freq, psd, f_low, f_cut))
        lnlike_bfs_map[param].append(lnlike(param_vec, best_fit_signal, f, psd, f_low, f_cut))
    plt.subplot(1,2,idx+1)
    plt.plot(param_range_map[param], lnlike_data_map[param])
    plt.plot(param_range_map[param], lnlike_bfs_map[param])
    plt.xlabel(param)
    plt.ylabel('lnlike')
    
plt.show()
# Out:
# f_Nyq = 1112.048747
# fM_band: 20.015189 Hz to 1112.018604 Hz
# fM_band: 0.012165 Hz to 0.675860 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.040174 secs
# f0 = 0.012165 ini_offset_phen_p = 103.894314
# ...... generated the phen ampl in 0.074288 sec
# ...... generated the phen phase in 0.055762 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.136528 secs
# mtot = 123.394256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1112.048747
# fM_band: 20.015189 Hz to 1112.018604 Hz
# fM_band: 0.012165 Hz to 0.675860 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036340 secs
# f0 = 0.012165 ini_offset_phen_p = 103.894314
# ...... generated the phen ampl in 0.051651 sec
# ...... generated the phen phase in 0.050599 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.108405 secs
# mtot = 123.394256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1111.385594
# fM_band: 20.015189 Hz to 1111.355450 Hz
# fM_band: 0.012236 Hz to 0.679395 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036354 secs
# f0 = 0.012236 ini_offset_phen_p = 104.321393
# ...... generated the phen ampl in 0.052209 sec
# ...... generated the phen phase in 0.050659 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000053 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.108812 secs
# mtot = 124.113756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1111.385594
# fM_band: 20.015189 Hz to 1111.355450 Hz
# fM_band: 0.012236 Hz to 0.679395 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036812 secs
# f0 = 0.012236 ini_offset_phen_p = 104.321393
# ...... generated the phen ampl in 0.051840 sec
# ...... generated the phen phase in 0.051138 sec
# ...... generated the hyb data in 0.000002 sec
# ...... generated the hyb data2 in 0.000055 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.109201 secs
# mtot = 124.113756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1110.752583
# fM_band: 20.015189 Hz to 1110.722440 Hz
# fM_band: 0.012307 Hz to 0.682944 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036334 secs
# f0 = 0.012307 ini_offset_phen_p = 104.743872
# ...... generated the phen ampl in 0.052104 sec
# ...... generated the phen phase in 0.050661 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.108851 secs
# mtot = 124.833256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1110.752583
# fM_band: 20.015189 Hz to 1110.722440 Hz
# fM_band: 0.012307 Hz to 0.682944 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036060 secs
# f0 = 0.012307 ini_offset_phen_p = 104.743872
# ...... generated the phen ampl in 0.051616 sec
# ...... generated the phen phase in 0.050273 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.108088 secs
# mtot = 124.833256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1110.119573
# fM_band: 20.015189 Hz to 1110.089429 Hz
# fM_band: 0.012378 Hz to 0.686489 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027443 secs
# f0 = 0.012378 ini_offset_phen_p = 105.161863
# ...... generated the phen ampl in 0.044857 sec
# ...... generated the phen phase in 0.038271 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.087923 secs
# mtot = 125.552756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1110.119573
# fM_band: 20.015189 Hz to 1110.089429 Hz
# fM_band: 0.012378 Hz to 0.686489 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026896 secs
# f0 = 0.012378 ini_offset_phen_p = 105.161863
# ...... generated the phen ampl in 0.039268 sec
# ...... generated the phen phase in 0.037504 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081935 secs
# mtot = 125.552756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1109.486562
# fM_band: 20.015189 Hz to 1109.456419 Hz
# fM_band: 0.012449 Hz to 0.690030 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027227 secs
# f0 = 0.012449 ini_offset_phen_p = 105.575476
# ...... generated the phen ampl in 0.039222 sec
# ...... generated the phen phase in 0.037874 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000052 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.082279 secs
# mtot = 126.272256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1109.486562
# fM_band: 20.015189 Hz to 1109.456419 Hz
# fM_band: 0.012449 Hz to 0.690030 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026853 secs
# f0 = 0.012449 ini_offset_phen_p = 105.575476
# ...... generated the phen ampl in 0.038461 sec
# ...... generated the phen phase in 0.050011 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000085 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.097708 secs
# mtot = 126.272256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1108.853552
# fM_band: 20.015189 Hz to 1108.823408 Hz
# fM_band: 0.012519 Hz to 0.693565 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.037421 secs
# f0 = 0.012519 ini_offset_phen_p = 105.984818
# ...... generated the phen ampl in 0.064937 sec
# ...... generated the phen phase in 0.051780 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000066 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.128051 secs
# mtot = 126.991756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1108.853552
# fM_band: 20.015189 Hz to 1108.823408 Hz
# fM_band: 0.012519 Hz to 0.693565 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.039802 secs
# f0 = 0.012519 ini_offset_phen_p = 105.984818
# ...... generated the phen ampl in 0.073657 sec
# ...... generated the phen phase in 0.054262 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000056 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.133982 secs
# mtot = 126.991756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1108.220541
# fM_band: 20.015189 Hz to 1108.190398 Hz
# fM_band: 0.012590 Hz to 0.697097 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036063 secs
# f0 = 0.012590 ini_offset_phen_p = 106.389993
# ...... generated the phen ampl in 0.051343 sec
# ...... generated the phen phase in 0.050283 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000055 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107954 secs
# mtot = 127.711256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1108.220541
# fM_band: 20.015189 Hz to 1108.190398 Hz
# fM_band: 0.012590 Hz to 0.697097 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035673 secs
# f0 = 0.012590 ini_offset_phen_p = 106.389993
# ...... generated the phen ampl in 0.050966 sec
# ...... generated the phen phase in 0.049405 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000056 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.187195 secs
# mtot = 127.711256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1107.617674
# fM_band: 20.015189 Hz to 1107.587531 Hz
# fM_band: 0.012661 Hz to 0.700643 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.040885 secs
# f0 = 0.012661 ini_offset_phen_p = 106.791101
# ...... generated the phen ampl in 0.075932 sec
# ...... generated the phen phase in 0.055456 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000057 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.137650 secs
# mtot = 128.430756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1107.617674
# fM_band: 20.015189 Hz to 1107.587531 Hz
# fM_band: 0.012661 Hz to 0.700643 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035938 secs
# f0 = 0.012661 ini_offset_phen_p = 106.791101
# ...... generated the phen ampl in 0.051626 sec
# ...... generated the phen phase in 0.049893 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000053 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107860 secs
# mtot = 128.430756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1107.014807
# fM_band: 20.015189 Hz to 1106.984663 Hz
# fM_band: 0.012732 Hz to 0.704184 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035815 secs
# f0 = 0.012732 ini_offset_phen_p = 107.188239
# ...... generated the phen ampl in 0.051258 sec
# ...... generated the phen phase in 0.049887 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.112211 secs
# mtot = 129.150256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1107.014807
# fM_band: 20.015189 Hz to 1106.984663 Hz
# fM_band: 0.012732 Hz to 0.704184 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.040472 secs
# f0 = 0.012732 ini_offset_phen_p = 107.188239
# ...... generated the phen ampl in 0.074955 sec
# ...... generated the phen phase in 0.054937 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000055 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.136154 secs
# mtot = 129.150256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1106.411940
# fM_band: 20.015189 Hz to 1106.381796 Hz
# fM_band: 0.012803 Hz to 0.707722 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035856 secs
# f0 = 0.012803 ini_offset_phen_p = 107.581504
# ...... generated the phen ampl in 0.051364 sec
# ...... generated the phen phase in 0.050022 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000057 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107237 secs
# mtot = 129.869756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1106.411940
# fM_band: 20.015189 Hz to 1106.381796 Hz
# fM_band: 0.012803 Hz to 0.707722 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035853 secs
# f0 = 0.012803 ini_offset_phen_p = 107.581504
# ...... generated the phen ampl in 0.051465 sec
# ...... generated the phen phase in 0.049782 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000056 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107548 secs
# mtot = 129.869756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1105.839216
# fM_band: 20.015189 Hz to 1105.809072 Hz
# fM_band: 0.012874 Hz to 0.711274 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036093 secs
# f0 = 0.012874 ini_offset_phen_p = 107.970988
# ...... generated the phen ampl in 0.051250 sec
# ...... generated the phen phase in 0.050146 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107633 secs
# mtot = 130.589256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1105.839216
# fM_band: 20.015189 Hz to 1105.809072 Hz
# fM_band: 0.012874 Hz to 0.711274 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035824 secs
# f0 = 0.012874 ini_offset_phen_p = 107.970988
# ...... generated the phen ampl in 0.051303 sec
# ...... generated the phen phase in 0.049859 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107334 secs
# mtot = 130.589256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1105.236349
# fM_band: 20.015189 Hz to 1105.206205 Hz
# fM_band: 0.012945 Hz to 0.714803 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035851 secs
# f0 = 0.012945 ini_offset_phen_p = 108.356780
# ...... generated the phen ampl in 0.051148 sec
# ...... generated the phen phase in 0.050085 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107559 secs
# mtot = 131.308756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1105.236349
# fM_band: 20.015189 Hz to 1105.206205 Hz
# fM_band: 0.012945 Hz to 0.714803 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027103 secs
# f0 = 0.012945 ini_offset_phen_p = 108.356780
# ...... generated the phen ampl in 0.046482 sec
# ...... generated the phen phase in 0.037708 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.088914 secs
# mtot = 131.308756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1104.663625
# fM_band: 20.015189 Hz to 1104.633481 Hz
# fM_band: 0.013016 Hz to 0.718348 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027045 secs
# f0 = 0.013016 ini_offset_phen_p = 108.738968
# ...... generated the phen ampl in 0.040202 sec
# ...... generated the phen phase in 0.038278 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000043 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.083199 secs
# mtot = 132.028256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1104.663625
# fM_band: 20.015189 Hz to 1104.633481 Hz
# fM_band: 0.013016 Hz to 0.718348 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027016 secs
# f0 = 0.013016 ini_offset_phen_p = 108.738968
# ...... generated the phen ampl in 0.039022 sec
# ...... generated the phen phase in 0.037530 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081281 secs
# mtot = 132.028256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1104.090901
# fM_band: 20.015189 Hz to 1104.060758 Hz
# fM_band: 0.013087 Hz to 0.721888 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026912 secs
# f0 = 0.013087 ini_offset_phen_p = 109.117636
# ...... generated the phen ampl in 0.038568 sec
# ...... generated the phen phase in 0.037425 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080670 secs
# mtot = 132.747756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1104.090901
# fM_band: 20.015189 Hz to 1104.060758 Hz
# fM_band: 0.013087 Hz to 0.721888 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026972 secs
# f0 = 0.013087 ini_offset_phen_p = 109.117636
# ...... generated the phen ampl in 0.039204 sec
# ...... generated the phen phase in 0.037660 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.082311 secs
# mtot = 132.747756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1103.518177
# fM_band: 20.015189 Hz to 1103.488034 Hz
# fM_band: 0.013158 Hz to 0.725424 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.041323 secs
# f0 = 0.013158 ini_offset_phen_p = 109.492868
# ...... generated the phen ampl in 0.076988 sec
# ...... generated the phen phase in 0.055675 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000052 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.138989 secs
# mtot = 133.467256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1103.518177
# fM_band: 20.015189 Hz to 1103.488034 Hz
# fM_band: 0.013158 Hz to 0.725424 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035853 secs
# f0 = 0.013158 ini_offset_phen_p = 109.492868
# ...... generated the phen ampl in 0.051710 sec
# ...... generated the phen phase in 0.050003 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000057 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.108059 secs
# mtot = 133.467256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1102.945453
# fM_band: 20.015189 Hz to 1102.915310 Hz
# fM_band: 0.013229 Hz to 0.728956 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035771 secs
# f0 = 0.013229 ini_offset_phen_p = 109.864743
# ...... generated the phen ampl in 0.051149 sec
# ...... generated the phen phase in 0.049832 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000056 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107170 secs
# mtot = 134.186756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1102.945453
# fM_band: 20.015189 Hz to 1102.915310 Hz
# fM_band: 0.013229 Hz to 0.728956 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035759 secs
# f0 = 0.013229 ini_offset_phen_p = 109.864743
# ...... generated the phen ampl in 0.051100 sec
# ...... generated the phen phase in 0.050027 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000057 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107379 secs
# mtot = 134.186756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1102.402873
# fM_band: 20.015189 Hz to 1102.372730 Hz
# fM_band: 0.013300 Hz to 0.732504 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035766 secs
# f0 = 0.013300 ini_offset_phen_p = 110.233341
# ...... generated the phen ampl in 0.051227 sec
# ...... generated the phen phase in 0.049855 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000056 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107163 secs
# mtot = 134.906256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1102.402873
# fM_band: 20.015189 Hz to 1102.372730 Hz
# fM_band: 0.013300 Hz to 0.732504 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036131 secs
# f0 = 0.013300 ini_offset_phen_p = 110.233341
# ...... generated the phen ampl in 0.051335 sec
# ...... generated the phen phase in 0.050131 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000057 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107896 secs
# mtot = 134.906256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1101.860293
# fM_band: 20.015189 Hz to 1101.830149 Hz
# fM_band: 0.013371 Hz to 0.736048 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.028360 secs
# f0 = 0.013371 ini_offset_phen_p = 110.598736
# ...... generated the phen ampl in 0.051353 sec
# ...... generated the phen phase in 0.039179 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000044 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.095658 secs
# mtot = 135.625756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1101.860293
# fM_band: 20.015189 Hz to 1101.830149 Hz
# fM_band: 0.013371 Hz to 0.736048 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027000 secs
# f0 = 0.013371 ini_offset_phen_p = 110.598736
# ...... generated the phen ampl in 0.039184 sec
# ...... generated the phen phase in 0.037865 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000045 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081721 secs
# mtot = 135.625756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1101.317712
# fM_band: 20.015189 Hz to 1101.287569 Hz
# fM_band: 0.013442 Hz to 0.739589 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026978 secs
# f0 = 0.013442 ini_offset_phen_p = 110.961003
# ...... generated the phen ampl in 0.038922 sec
# ...... generated the phen phase in 0.037577 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000061 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081602 secs
# mtot = 136.345256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1101.317712
# fM_band: 20.015189 Hz to 1101.287569 Hz
# fM_band: 0.013442 Hz to 0.739589 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026785 secs
# f0 = 0.013442 ini_offset_phen_p = 110.961003
# ...... generated the phen ampl in 0.038303 sec
# ...... generated the phen phase in 0.037477 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080613 secs
# mtot = 136.345256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1100.775132
# fM_band: 20.015189 Hz to 1100.744988 Hz
# fM_band: 0.013512 Hz to 0.743125 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026838 secs
# f0 = 0.013512 ini_offset_phen_p = 111.320214
# ...... generated the phen ampl in 0.039333 sec
# ...... generated the phen phase in 0.037453 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081880 secs
# mtot = 137.064756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1100.775132
# fM_band: 20.015189 Hz to 1100.744988 Hz
# fM_band: 0.013512 Hz to 0.743125 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026879 secs
# f0 = 0.013512 ini_offset_phen_p = 111.320214
# ...... generated the phen ampl in 0.038939 sec
# ...... generated the phen phase in 0.037633 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000043 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081347 secs
# mtot = 137.064756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1100.232551
# fM_band: 20.015189 Hz to 1100.202408 Hz
# fM_band: 0.013583 Hz to 0.746658 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026929 secs
# f0 = 0.013583 ini_offset_phen_p = 111.676438
# ...... generated the phen ampl in 0.038788 sec
# ...... generated the phen phase in 0.037481 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000043 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080946 secs
# mtot = 137.784256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1100.232551
# fM_band: 20.015189 Hz to 1100.202408 Hz
# fM_band: 0.013583 Hz to 0.746658 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026805 secs
# f0 = 0.013583 ini_offset_phen_p = 111.676438
# ...... generated the phen ampl in 0.038627 sec
# ...... generated the phen phase in 0.037584 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080960 secs
# mtot = 137.784256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1099.720114
# fM_band: 20.015189 Hz to 1099.689971 Hz
# fM_band: 0.013654 Hz to 0.750207 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026939 secs
# f0 = 0.013654 ini_offset_phen_p = 112.029745
# ...... generated the phen ampl in 0.038732 sec
# ...... generated the phen phase in 0.037654 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000057 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081219 secs
# mtot = 138.503756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1099.720114
# fM_band: 20.015189 Hz to 1099.689971 Hz
# fM_band: 0.013654 Hz to 0.750207 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026845 secs
# f0 = 0.013654 ini_offset_phen_p = 112.029745
# ...... generated the phen ampl in 0.038796 sec
# ...... generated the phen phase in 0.037274 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081933 secs
# mtot = 138.503756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1099.207677
# fM_band: 20.015189 Hz to 1099.177534 Hz
# fM_band: 0.013725 Hz to 0.753753 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.039842 secs
# f0 = 0.013725 ini_offset_phen_p = 112.380200
# ...... generated the phen ampl in 0.072729 sec
# ...... generated the phen phase in 0.053926 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000052 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.132605 secs
# mtot = 139.223256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1099.207677
# fM_band: 20.015189 Hz to 1099.177534 Hz
# fM_band: 0.013725 Hz to 0.753753 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035613 secs
# f0 = 0.013725 ini_offset_phen_p = 112.380200
# ...... generated the phen ampl in 0.050870 sec
# ...... generated the phen phase in 0.049608 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.106361 secs
# mtot = 139.223256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1098.695240
# fM_band: 20.015189 Hz to 1098.665097 Hz
# fM_band: 0.013796 Hz to 0.757295 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035700 secs
# f0 = 0.013796 ini_offset_phen_p = 112.727868
# ...... generated the phen ampl in 0.051048 sec
# ...... generated the phen phase in 0.049598 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.106716 secs
# mtot = 139.942756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1098.695240
# fM_band: 20.015189 Hz to 1098.665097 Hz
# fM_band: 0.013796 Hz to 0.757295 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035733 secs
# f0 = 0.013796 ini_offset_phen_p = 112.727868
# ...... generated the phen ampl in 0.051119 sec
# ...... generated the phen phase in 0.049884 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107135 secs
# mtot = 139.942756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1098.182803
# fM_band: 20.015189 Hz to 1098.152660 Hz
# fM_band: 0.013867 Hz to 0.760834 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035499 secs
# f0 = 0.013867 ini_offset_phen_p = 113.072812
# ...... generated the phen ampl in 0.050802 sec
# ...... generated the phen phase in 0.049364 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.106472 secs
# mtot = 140.662256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1098.182803
# fM_band: 20.015189 Hz to 1098.152660 Hz
# fM_band: 0.013867 Hz to 0.760834 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035537 secs
# f0 = 0.013867 ini_offset_phen_p = 113.072812
# ...... generated the phen ampl in 0.050871 sec
# ...... generated the phen phase in 0.049676 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.106615 secs
# mtot = 140.662256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1097.670366
# fM_band: 20.015189 Hz to 1097.640223 Hz
# fM_band: 0.013938 Hz to 0.764369 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026937 secs
# f0 = 0.013938 ini_offset_phen_p = 113.415093
# ...... generated the phen ampl in 0.040551 sec
# ...... generated the phen phase in 0.037615 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.082938 secs
# mtot = 141.381756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1097.670366
# fM_band: 20.015189 Hz to 1097.640223 Hz
# fM_band: 0.013938 Hz to 0.764369 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026770 secs
# f0 = 0.013938 ini_offset_phen_p = 113.415093
# ...... generated the phen ampl in 0.038492 sec
# ...... generated the phen phase in 0.037272 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000052 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080463 secs
# mtot = 141.381756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1097.157929
# fM_band: 20.015189 Hz to 1097.127785 Hz
# fM_band: 0.014009 Hz to 0.767900 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026684 secs
# f0 = 0.014009 ini_offset_phen_p = 113.754771
# ...... generated the phen ampl in 0.038416 sec
# ...... generated the phen phase in 0.037371 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080354 secs
# mtot = 142.101256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1097.157929
# fM_band: 20.015189 Hz to 1097.127785 Hz
# fM_band: 0.014009 Hz to 0.767900 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026781 secs
# f0 = 0.014009 ini_offset_phen_p = 113.754771
# ...... generated the phen ampl in 0.038747 sec
# ...... generated the phen phase in 0.037302 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000039 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080673 secs
# mtot = 142.101256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1096.675635
# fM_band: 20.015189 Hz to 1096.645492 Hz
# fM_band: 0.014080 Hz to 0.771449 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026786 secs
# f0 = 0.014080 ini_offset_phen_p = 114.091904
# ...... generated the phen ampl in 0.038498 sec
# ...... generated the phen phase in 0.037367 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000052 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080493 secs
# mtot = 142.820756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1096.675635
# fM_band: 20.015189 Hz to 1096.645492 Hz
# fM_band: 0.014080 Hz to 0.771449 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026704 secs
# f0 = 0.014080 ini_offset_phen_p = 114.091904
# ...... generated the phen ampl in 0.038444 sec
# ...... generated the phen phase in 0.037289 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080669 secs
# mtot = 142.820756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1096.193341
# fM_band: 20.015189 Hz to 1096.163198 Hz
# fM_band: 0.014151 Hz to 0.774994 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026646 secs
# f0 = 0.014151 ini_offset_phen_p = 114.426548
# ...... generated the phen ampl in 0.038111 sec
# ...... generated the phen phase in 0.037192 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080002 secs
# mtot = 143.540256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1096.193341
# fM_band: 20.015189 Hz to 1096.163198 Hz
# fM_band: 0.014151 Hz to 0.774994 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026726 secs
# f0 = 0.014151 ini_offset_phen_p = 114.426548
# ...... generated the phen ampl in 0.038476 sec
# ...... generated the phen phase in 0.037217 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080659 secs
# mtot = 143.540256 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1095.711048
# fM_band: 20.015189 Hz to 1095.680904 Hz
# fM_band: 0.014222 Hz to 0.778536 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026943 secs
# f0 = 0.014222 ini_offset_phen_p = 114.758759
# ...... generated the phen ampl in 0.038764 sec
# ...... generated the phen phase in 0.037545 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080728 secs
# mtot = 144.259756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1095.711048
# fM_band: 20.015189 Hz to 1095.680904 Hz
# fM_band: 0.014222 Hz to 0.778536 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026793 secs
# f0 = 0.014222 ini_offset_phen_p = 114.758759
# ...... generated the phen ampl in 0.038611 sec
# ...... generated the phen phase in 0.037316 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080391 secs
# mtot = 144.259756 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1095.228754
# fM_band: 20.015189 Hz to 1095.198611 Hz
# fM_band: 0.014293 Hz to 0.782075 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026752 secs
# f0 = 0.014293 ini_offset_phen_p = 115.088590
# ...... generated the phen ampl in 0.039525 sec
# ...... generated the phen phase in 0.037406 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000043 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081610 secs
# mtot = 144.979257 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1095.228754
# fM_band: 20.015189 Hz to 1095.198611 Hz
# fM_band: 0.014293 Hz to 0.782075 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026864 secs
# f0 = 0.014293 ini_offset_phen_p = 115.088590
# ...... generated the phen ampl in 0.038688 sec
# ...... generated the phen phase in 0.037406 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000039 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080679 secs
# mtot = 144.979257 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1094.746460
# fM_band: 20.015189 Hz to 1094.716317 Hz
# fM_band: 0.014364 Hz to 0.785610 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026624 secs
# f0 = 0.014364 ini_offset_phen_p = 115.416094
# ...... generated the phen ampl in 0.038274 sec
# ...... generated the phen phase in 0.037141 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080309 secs
# mtot = 145.698757 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1094.746460
# fM_band: 20.015189 Hz to 1094.716317 Hz
# fM_band: 0.014364 Hz to 0.785610 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026958 secs
# f0 = 0.014364 ini_offset_phen_p = 115.416094
# ...... generated the phen ampl in 0.039231 sec
# ...... generated the phen phase in 0.037487 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081318 secs
# mtot = 145.698757 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1094.264166
# fM_band: 20.015189 Hz to 1094.234023 Hz
# fM_band: 0.014435 Hz to 0.789142 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026678 secs
# f0 = 0.014435 ini_offset_phen_p = 115.741321
# ...... generated the phen ampl in 0.038487 sec
# ...... generated the phen phase in 0.037758 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080850 secs
# mtot = 146.418257 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1094.264166
# fM_band: 20.015189 Hz to 1094.234023 Hz
# fM_band: 0.014435 Hz to 0.789142 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026545 secs
# f0 = 0.014435 ini_offset_phen_p = 115.741321
# ...... generated the phen ampl in 0.038426 sec
# ...... generated the phen phase in 0.037000 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080150 secs
# mtot = 146.418257 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1093.812016
# fM_band: 20.015189 Hz to 1093.781873 Hz
# fM_band: 0.014506 Hz to 0.792692 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026516 secs
# f0 = 0.014506 ini_offset_phen_p = 116.064321
# ...... generated the phen ampl in 0.038198 sec
# ...... generated the phen phase in 0.037104 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080137 secs
# mtot = 147.137757 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1093.812016
# fM_band: 20.015189 Hz to 1093.781873 Hz
# fM_band: 0.014506 Hz to 0.792692 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026551 secs
# f0 = 0.014506 ini_offset_phen_p = 116.064321
# ...... generated the phen ampl in 0.038517 sec
# ...... generated the phen phase in 0.037051 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000046 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.080529 secs
# mtot = 147.137757 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1093.359866
# fM_band: 20.015189 Hz to 1093.329722 Hz
# fM_band: 0.014576 Hz to 0.796239 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026614 secs
# f0 = 0.014576 ini_offset_phen_p = 116.385143
# ...... generated the phen ampl in 0.038211 sec
# ...... generated the phen phase in 0.036930 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.079740 secs
# mtot = 147.857257 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1093.359866
# fM_band: 20.015189 Hz to 1093.329722 Hz
# fM_band: 0.014576 Hz to 0.796239 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026534 secs
# f0 = 0.014576 ini_offset_phen_p = 116.385143
# ...... generated the phen ampl in 0.038192 sec
# ...... generated the phen phase in 0.037018 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.079784 secs
# mtot = 147.857257 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1092.877572
# fM_band: 20.015189 Hz to 1092.847429 Hz
# fM_band: 0.014647 Hz to 0.799760 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.042506 secs
# f0 = 0.014647 ini_offset_phen_p = 116.703834
# ...... generated the phen ampl in 0.081493 sec
# ...... generated the phen phase in 0.057079 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000052 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.144710 secs
# mtot = 148.576757 eta = 0.122449 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1092.877572
# fM_band: 20.015189 Hz to 1092.847429 Hz
# fM_band: 0.014647 Hz to 0.799760 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035290 secs
# f0 = 0.014647 ini_offset_phen_p = 116.703834
# ...... generated the phen ampl in 0.050529 sec
# ...... generated the phen phase in 0.049170 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000050 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.105804 secs
# ...
# fM_band: 20.015189 Hz to 1101.830149 Hz
# fM_band: 0.013437 Hz to 0.739685 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035979 secs
# f0 = 0.013437 ini_offset_phen_p = 107.942146
# ...... generated the phen ampl in 0.051358 sec
# ...... generated the phen phase in 0.050160 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000057 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107874 secs
# mtot = 136.295938 eta = 0.128045 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1101.860293
# fM_band: 20.015189 Hz to 1101.830149 Hz
# fM_band: 0.013437 Hz to 0.739685 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035732 secs
# f0 = 0.013437 ini_offset_phen_p = 107.942146
# ...... generated the phen ampl in 0.051366 sec
# ...... generated the phen phase in 0.049774 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000058 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107321 secs
# mtot = 136.295938 eta = 0.128045 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1102.463160
# fM_band: 20.015189 Hz to 1102.433016 Hz
# fM_band: 0.013373 Hz to 0.736562 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035804 secs
# f0 = 0.013373 ini_offset_phen_p = 107.096935
# ...... generated the phen ampl in 0.051339 sec
# ...... generated the phen phase in 0.050124 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000057 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107716 secs
# mtot = 135.646094 eta = 0.129069 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1102.463160
# fM_band: 20.015189 Hz to 1102.433016 Hz
# fM_band: 0.013373 Hz to 0.736562 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027021 secs
# f0 = 0.013373 ini_offset_phen_p = 107.096935
# ...... generated the phen ampl in 0.048456 sec
# ...... generated the phen phase in 0.038001 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000044 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.091212 secs
# mtot = 135.646094 eta = 0.129069 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1103.066027
# fM_band: 20.015189 Hz to 1103.035884 Hz
# fM_band: 0.013310 Hz to 0.733505 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027117 secs
# f0 = 0.013310 ini_offset_phen_p = 106.268167
# ...... generated the phen ampl in 0.039172 sec
# ...... generated the phen phase in 0.038725 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000260 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.082674 secs
# mtot = 135.009324 eta = 0.130086 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1103.066027
# fM_band: 20.015189 Hz to 1103.035884 Hz
# fM_band: 0.013310 Hz to 0.733505 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027211 secs
# f0 = 0.013310 ini_offset_phen_p = 106.268167
# ...... generated the phen ampl in 0.038965 sec
# ...... generated the phen phase in 0.037938 sec
# ...... generated the hyb data in 0.000000 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081540 secs
# mtot = 135.009324 eta = 0.130086 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=6 lmax = 4
# f_Nyq = 1103.638751
# fM_band: 20.015189 Hz to 1103.608607 Hz
# fM_band: 0.013248 Hz to 0.730493 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027100 secs
# f0 = 0.013248 ini_offset_phen_p = 105.455736
# ...... generated the phen ampl in 0.038915 sec
# ...... generated the phen phase in 0.037702 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081438 secs
# mtot = 134.385242 eta = 0.131095 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1103.638751
# fM_band: 20.015189 Hz to 1103.608607 Hz
# fM_band: 0.013248 Hz to 0.730493 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027180 secs
# f0 = 0.013248 ini_offset_phen_p = 105.455736
# ...... generated the phen ampl in 0.038993 sec
# ...... generated the phen phase in 0.038042 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000043 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081969 secs
# mtot = 134.385242 eta = 0.131095 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1104.211474
# fM_band: 20.015189 Hz to 1104.181331 Hz
# fM_band: 0.013188 Hz to 0.727545 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027104 secs
# f0 = 0.013188 ini_offset_phen_p = 104.659540
# ...... generated the phen ampl in 0.038934 sec
# ...... generated the phen phase in 0.037833 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081991 secs
# mtot = 133.773476 eta = 0.132095 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1104.211474
# fM_band: 20.015189 Hz to 1104.181331 Hz
# fM_band: 0.013188 Hz to 0.727545 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026913 secs
# f0 = 0.013188 ini_offset_phen_p = 104.659540
# ...... generated the phen ampl in 0.038666 sec
# ...... generated the phen phase in 0.037582 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081263 secs
# mtot = 133.773476 eta = 0.132095 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1104.784198
# fM_band: 20.015189 Hz to 1104.754055 Hz
# fM_band: 0.013129 Hz to 0.724659 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027266 secs
# f0 = 0.013129 ini_offset_phen_p = 103.878659
# ...... generated the phen ampl in 0.039826 sec
# ...... generated the phen phase in 0.038109 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000045 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.082624 secs
# mtot = 133.173672 eta = 0.133087 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1104.784198
# fM_band: 20.015189 Hz to 1104.754055 Hz
# fM_band: 0.013129 Hz to 0.724659 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027000 secs
# f0 = 0.013129 ini_offset_phen_p = 103.878659
# ...... generated the phen ampl in 0.039062 sec
# ...... generated the phen phase in 0.037780 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000041 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081747 secs
# mtot = 133.173672 eta = 0.133087 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1105.356922
# fM_band: 20.015189 Hz to 1105.326779 Hz
# fM_band: 0.013071 Hz to 0.721832 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027254 secs
# f0 = 0.013071 ini_offset_phen_p = 103.112177
# ...... generated the phen ampl in 0.039379 sec
# ...... generated the phen phase in 0.038105 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.082176 secs
# mtot = 132.585486 eta = 0.134073 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1105.356922
# fM_band: 20.015189 Hz to 1105.326779 Hz
# fM_band: 0.013071 Hz to 0.721832 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026867 secs
# f0 = 0.013071 ini_offset_phen_p = 103.112177
# ...... generated the phen ampl in 0.039564 sec
# ...... generated the phen phase in 0.037494 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.082331 secs
# mtot = 132.585486 eta = 0.134073 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1105.929646
# fM_band: 20.015189 Hz to 1105.899503 Hz
# fM_band: 0.013014 Hz to 0.719064 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.041640 secs
# f0 = 0.013014 ini_offset_phen_p = 102.360820
# ...... generated the phen ampl in 0.078717 sec
# ...... generated the phen phase in 0.056267 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000051 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.141426 secs
# mtot = 132.008591 eta = 0.135051 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1105.929646
# fM_band: 20.015189 Hz to 1105.899503 Hz
# fM_band: 0.013014 Hz to 0.719064 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035732 secs
# f0 = 0.013014 ini_offset_phen_p = 102.360820
# ...... generated the phen ampl in 0.051330 sec
# ...... generated the phen phase in 0.049566 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000053 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.106967 secs
# mtot = 132.008591 eta = 0.135051 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1106.502370
# fM_band: 20.015189 Hz to 1106.472226 Hz
# fM_band: 0.012958 Hz to 0.716352 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035745 secs
# f0 = 0.012958 ini_offset_phen_p = 101.622857
# ...... generated the phen ampl in 0.051056 sec
# ...... generated the phen phase in 0.049639 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107134 secs
# mtot = 131.442668 eta = 0.136022 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1106.502370
# fM_band: 20.015189 Hz to 1106.472226 Hz
# fM_band: 0.012958 Hz to 0.716352 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.036190 secs
# f0 = 0.012958 ini_offset_phen_p = 101.622857
# ...... generated the phen ampl in 0.051086 sec
# ...... generated the phen phase in 0.050216 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000054 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107687 secs
# mtot = 131.442668 eta = 0.136022 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1107.044950
# fM_band: 20.015189 Hz to 1107.014807 Hz
# fM_band: 0.012903 Hz to 0.713676 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035683 secs
# f0 = 0.012903 ini_offset_phen_p = 100.899020
# ...... generated the phen ampl in 0.051011 sec
# ...... generated the phen phase in 0.049826 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000061 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107341 secs
# mtot = 130.887415 eta = 0.136984 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1107.044950
# fM_band: 20.015189 Hz to 1107.014807 Hz
# fM_band: 0.012903 Hz to 0.713676 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.035812 secs
# f0 = 0.012903 ini_offset_phen_p = 100.899020
# ...... generated the phen ampl in 0.051402 sec
# ...... generated the phen phase in 0.050153 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000055 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.107725 secs
# mtot = 130.887415 eta = 0.136984 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1107.587531
# fM_band: 20.015189 Hz to 1107.557387 Hz
# fM_band: 0.012850 Hz to 0.711053 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027429 secs
# f0 = 0.012850 ini_offset_phen_p = 100.187581
# ...... generated the phen ampl in 0.049858 sec
# ...... generated the phen phase in 0.038083 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000042 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.092959 secs
# mtot = 130.342537 eta = 0.137941 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1107.587531
# fM_band: 20.015189 Hz to 1107.557387 Hz
# fM_band: 0.012850 Hz to 0.711053 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027285 secs
# f0 = 0.012850 ini_offset_phen_p = 100.187581
# ...... generated the phen ampl in 0.039278 sec
# ...... generated the phen phase in 0.038554 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000043 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.082756 secs
# mtot = 130.342537 eta = 0.137941 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1108.160254
# fM_band: 20.015189 Hz to 1108.130111 Hz
# fM_band: 0.012797 Hz to 0.708502 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.027196 secs
# f0 = 0.012797 ini_offset_phen_p = 99.490101
# ...... generated the phen ampl in 0.038857 sec
# ...... generated the phen phase in 0.037719 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000052 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081289 secs
# mtot = 129.807754 eta = 0.138889 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
# f_Nyq = 1108.160254
# fM_band: 20.015189 Hz to 1108.130111 Hz
# fM_band: 0.012797 Hz to 0.708502 Hz
# ......... using template mode l = 2 m  =  2
# ......... generated taylorf2 phase in 0.026919 secs
# f0 = 0.012797 ini_offset_phen_p = 99.490101
# ...... generated the phen ampl in 0.038605 sec
# ...... generated the phen phase in 0.037480 sec
# ...... generated the hyb data in 0.000001 sec
# ...... generated the hyb data2 in 0.000040 sec
# ..printing Psi_ref
# 0.0
# ..... time taken to generate phenomhm = 0.081186 secs
# mtot = 129.807754 eta = 0.138889 t0 = 0.000000 phi0 = 0.000000 chi1 = 0.000000 chi2 = 0.000000 ampO = 7 phaseO = 7 incl_angle = 0.000000 phi = 0.000000 q=5 lmax = 4
